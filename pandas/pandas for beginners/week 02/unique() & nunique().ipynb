# %% [raw]
# In this week, I am going to explain two practical objects in pandas;

# %%
import pandas as pd

# %%
df = pd.read_csv('Classification with an Academic Success Dataset.csv')
df.sample(6) # df.sample(number of rows we want to be shown randomly)
# Out:
#           id  Marital status  Application mode  Application order  Course  \
# 32274  32274               1                 1                  2    9070
# 69599  69599               1                 1                  2    9773
# 3925    3925               2                39                  1    9991
# 32981  32981               1                17                  2    9238
# 18738  18738               1                17                  1    9991
# 12044  12044               1                 1                  3    9238
#
#        Daytime/evening attendance  Previous qualification  \
# 32274                           1                       1
# 69599                           1                       1
# 3925                            0                      19
# 32981                           1                       1
# 18738                           0                       1
# 12044                           1                       1
#
# ...

# %%
df['Target'].nunique() #it shows us "how many" specific string do we have in Target column.
# Out:
# 3

# %%
df['Target'].unique() #it shows us "the name" of the specific string we have in Target column.
# Out:
# array(['Graduate', 'Dropout', 'Enrolled'], dtype=object)
